# %% [markdown]
# # Actividad número 9: Analisis de los datasets con Jupyter-Lab

# %% [markdown]
# ## Instalamos las librerias (en caso de necesitarlas)

# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-3.0.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Downloading numpy-2.5.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/persigo12/proyectos/escuela/pps/jupyter-proyecto/venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/persigo12/proyectos/escuela/pps/jupyter-proyecto/venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (10.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 5.7 MB/s  0:00:015.8 MB/s eta 0:00:0101
# Downloading numpy-2.5.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 5.8 MB/s  0:00:02m 6.0 MB/s eta 0:00:01
# Installing collected packages: numpy, pandas
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pandas]━━━━ 1/2 [pandas]
# Successfully installed numpy-2.5.1 pandas-3.0.3

# %%
# !pip install plotly
# Out:
# Collecting plotly
#   Downloading plotly-6.9.0-py3-none-any.whl.metadata (9.0 kB)
# Collecting narwhals>=1.15.1 (from plotly)
#   Downloading narwhals-2.24.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging in /home/persigo12/proyectos/escuela/pps/jupyter-proyecto/venv/lib/python3.12/site-packages (from plotly) (26.2)
# Downloading plotly-6.9.0-py3-none-any.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 5.6 MB/s  0:00:01m 5.8 MB/s eta 0:00:01
# Downloading narwhals-2.24.0-py3-none-any.whl (461 kB)
# Installing collected packages: narwhals, plotly
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [plotly]━━━━ 1/2 [plotly]
# Successfully installed narwhals-2.24.0 plotly-6.9.0

# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in /home/persigo12/proyectos/escuela/pps/jupyter-proyecto/venv/lib/python3.12/site-packages (0.20.0)
# Requirement already satisfied: branca>=0.6.0 in /home/persigo12/proyectos/escuela/pps/jupyter-proyecto/venv/lib/python3.12/site-packages (from folium) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in /home/persigo12/proyectos/escuela/pps/jupyter-proyecto/venv/lib/python3.12/site-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in /home/persigo12/proyectos/escuela/pps/jupyter-proyecto/venv/lib/python3.12/site-packages (from folium) (2.5.1)
# Requirement already satisfied: requests in /home/persigo12/proyectos/escuela/pps/jupyter-proyecto/venv/lib/python3.12/site-packages (from folium) (2.34.2)
# Requirement already satisfied: xyzservices in /home/persigo12/proyectos/escuela/pps/jupyter-proyecto/venv/lib/python3.12/site-packages (from folium) (2026.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/persigo12/proyectos/escuela/pps/jupyter-proyecto/venv/lib/python3.12/site-packages (from jinja2>=2.9->folium) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/persigo12/proyectos/escuela/pps/jupyter-proyecto/venv/lib/python3.12/site-packages (from requests->folium) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /home/persigo12/proyectos/escuela/pps/jupyter-proyecto/venv/lib/python3.12/site-packages (from requests->folium) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /home/persigo12/proyectos/escuela/pps/jupyter-proyecto/venv/lib/python3.12/site-packages (from requests->folium) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /home/persigo12/proyectos/escuela/pps/jupyter-proyecto/venv/lib/python3.12/site-packages (from requests->folium) (2026.6.17)

# %% [markdown]
# ## Importamos Pandas y Plotly

# %%
import pandas as pd

# %%
import plotly.express as px

# %%
import folium as fl

# %% [markdown]
# ## Definimos las variables

# %%
felinos = pd.read_csv("felinos_filtrado.csv")

# %% [markdown]
# ## Información general: ¿Cuántos registros de avistajes hay? ¿Cuántas especies diferentes se registraron?

# %%
print(felinos.shape)
# Out:
# (2019, 19)

# %% [markdown]
# ### rt: El dataset tiene 2019 registros (y 19 columnas)

# %%
filtro_especies = felinos["species"]

# %%
print(filtro_especies.unique())
# Out:
# <StringArray>
# [  'Puma yagouaroundi',       'Puma concolor',       'Panthera onca',
#  'Leopardus geoffroyi',    'Leopardus guigna', 'Leopardus pajonales',
#   'Leopardus tigrinus',  'Leopardus pardalis',    'Leopardus wiedii']
# Length: 9, dtype: str

# %% [markdown]
# ### rt: El dataset tiene 9 especies diferentes.

# %% [markdown]
# ## Frecuencias: ¿Cuál es la especie más avistada? ¿Qué provincia tiene más avistajes?

# %%
print(filtro_especies.value_counts())
# Out:
# species
# Puma concolor          1297
# Puma yagouaroundi       332
# Panthera onca           172
# Leopardus pardalis       81
# Leopardus geoffroyi      70
# Leopardus guigna         32
# Leopardus tigrinus       19
# Leopardus wiedii          9
# Leopardus pajonales       7
# Name: count, dtype: int64

# %% [markdown]
# ### rt: La especie mas avistada es Puma Concolor

# %%
print(felinos["stateProvince"].value_counts())
# Out:
# stateProvince
# Misiones               1253
# Santa Cruz              313
# Corrientes              178
# Formosa                  74
# Neuquén                  66
# Neuquén / Río Negro      44
# Chubut                   24
# Santa Fe                 24
# Entre Ríos               11
# La Pampa                 11
# Chaco                     5
# Córdoba                   3
# Tucumán                   1
# Neuquen                   1
# San Luis                  1
# Jujuy                     1
# Santa cruz                1
# Name: count, dtype: int64

# %% [markdown]
# ### rt: La provincia con más avistajes es Misiones

# %% [markdown]
# ## Filtros: Mostrar todos los avistajes del género Puma. ¿Cuántos son? Mostrar los avistajes ocurridos en Misiones.

# %%
pumas=felinos[felinos["genus"]=="Puma"]

# %%
pumas
# Out:
#       Unnamed: 0   kingdom    phylum     class      order   family genus  \
# 0              0  Animalia  Chordata  Mammalia  Carnivora  Felidae  Puma
# 1              1  Animalia  Chordata  Mammalia  Carnivora  Felidae  Puma
# 2              2  Animalia  Chordata  Mammalia  Carnivora  Felidae  Puma
# 3              3  Animalia  Chordata  Mammalia  Carnivora  Felidae  Puma
# 4              4  Animalia  Chordata  Mammalia  Carnivora  Felidae  Puma
# ...          ...       ...       ...       ...        ...      ...   ...
# 2014        2014  Animalia  Chordata  Mammalia  Carnivora  Felidae  Puma
# 2015        2015  Animalia  Chordata  Mammalia  Carnivora  Felidae  Puma
# 2016        2016  Animalia  Chordata  Mammalia  Carnivora  Felidae  Puma
# 2017        2017  Animalia  Chordata  Mammalia  Carnivora  Felidae  Puma
# 2018        2018  Animalia  Chordata  Mammalia  Carnivora  Felidae  Puma
#
#                 species                                           locality  \
# 0     Puma yagouaroundi    <p>Camino acceso al Destacamento Estero Poi</p>
# 1     Puma yagouaroundi               <p>Destacamento de Laguna Blanca</p>
# 2     Puma yagouaroundi                             <p>P.N. El Palmar.</p>
# 3     Puma yagouaroundi                    <p> RP Nº 86, Potrero Nº 15</p>
# 4     Puma yagouaroundi                <p> RP Nº 86, Potrero 2 Grande.</p>
# ...                 ...                                                ...
# 2014  Puma yagouaroundi                      <p>A.C, ex Acceso al area</p>
# 2015  Puma yagouaroundi                                   <p>Bº Gques.</p>
# 2016  Puma yagouaroundi  <p>AC - curva con araucarias a 50mts lomo de b...
# 2017  Puma yagouaroundi                            <p>Barrio Gpques AC</p>
# 2018      Puma concolor  <p>Cerro W. 47º 43,762' S y 72º 24,453' W . 22...
#
#      stateProvince       lat       lng  elevation   day  month    year  \
# 0          Formosa -25.12069 -58.18679        0.0  19.0    9.0  2006.0
# 1          Formosa -25.17201 -58.13073        0.0  20.0    9.0  2006.0
# 2       Entre Ríos -31.88614 -58.30839       24.0   8.0    9.0  2006.0
# 3       Corrientes -28.04421 -58.12875       69.0  29.0   11.0  2010.0
# 4       Corrientes -28.01889 -58.05301       74.0  17.0    6.0  2010.0
# ...            ...       ...       ...        ...   ...    ...     ...
# 2014      Misiones -25.69013 -54.45898      217.0   3.0    3.0  2005.0
# 2015      Misiones -25.67886 -54.45548      192.0  12.0    1.0  2005.0
# 2016      Misiones -25.65692 -54.45178      179.0  15.0    6.0  2005.0
# 2017      Misiones -25.67886 -54.45548      192.0  24.0    2.0  2004.0
# 2018    Santa cruz -47.74994 -72.36557     1654.0   3.0    2.0  2008.0
#
#       taxonKey     ScientificName  \
# 0      2435146  Puma yagouaroundi
# 1      2435146  Puma yagouaroundi
# 2      2435146  Puma yagouaroundi
# 3      2435146  Puma yagouaroundi
# 4      2435146  Puma yagouaroundi
# ...        ...                ...
# 2014   2435146  Puma yagouaroundi
# 2015   2435146  Puma yagouaroundi
# 2016   2435146  Puma yagouaroundi
# 2017   2435146  Puma yagouaroundi
# 2018   2435099      Puma concolor
#
#                                         VernacularNames
# 0                      Jaguarondi Jaguarundi Yaguarundi
# 1                      Jaguarondi Jaguarundi Yaguarundi
# 2                      Jaguarondi Jaguarundi Yaguarundi
# 3                      Jaguarondi Jaguarundi Yaguarundi
# 4                      Jaguarondi Jaguarundi Yaguarundi
# ...                                                 ...
# 2014                   Jaguarondi Jaguarundi Yaguarundi
# 2015                   Jaguarondi Jaguarundi Yaguarundi
# 2016                   Jaguarondi Jaguarundi Yaguarundi
# 2017                   Jaguarondi Jaguarundi Yaguarundi
# 2018  Red tiger Puma Cougar León colorado Onza berme...
#
# [1629 rows x 19 columns]

# %% [markdown]
# ### rt: Son 1629 registros de Puma

# %%
pumas["stateProvince"].value_counts()
# Out:
# stateProvince
# Misiones               992
# Santa Cruz             310
# Corrientes             151
# Neuquén                 60
# Formosa                 38
# Neuquén / Río Negro     27
# Chubut                  15
# La Pampa                11
# Santa Fe                 9
# Entre Ríos               4
# Chaco                    4
# Córdoba                  3
# Tucumán                  1
# Neuquen                  1
# San Luis                 1
# Jujuy                    1
# Santa cruz               1
# Name: count, dtype: int64

# %%
pumas[pumas["stateProvince"]=="Misiones"]
# Out:
#       Unnamed: 0   kingdom    phylum     class      order   family genus  \
# 21            21  Animalia  Chordata  Mammalia  Carnivora  Felidae  Puma
# 22            22  Animalia  Chordata  Mammalia  Carnivora  Felidae  Puma
# 23            23  Animalia  Chordata  Mammalia  Carnivora  Felidae  Puma
# 24            24  Animalia  Chordata  Mammalia  Carnivora  Felidae  Puma
# 25            25  Animalia  Chordata  Mammalia  Carnivora  Felidae  Puma
# ...          ...       ...       ...       ...        ...      ...   ...
# 2013        2013  Animalia  Chordata  Mammalia  Carnivora  Felidae  Puma
# 2014        2014  Animalia  Chordata  Mammalia  Carnivora  Felidae  Puma
# 2015        2015  Animalia  Chordata  Mammalia  Carnivora  Felidae  Puma
# 2016        2016  Animalia  Chordata  Mammalia  Carnivora  Felidae  Puma
# 2017        2017  Animalia  Chordata  Mammalia  Carnivora  Felidae  Puma
#
#                 species                                           locality  \
# 21    Puma yagouaroundi       <p>Cruce de RN Nº 12 y RN Nº 101 <br /> </p>
# 22    Puma yagouaroundi  <p>Area Cataratas. Cruce de control, cerca<br ...
# 23    Puma yagouaroundi  <p>RN Nº 101 y Ruta Acceso Area Cataratas. Cru...
# 24    Puma yagouaroundi                            <p>RN Nº 101<br /> </p>
# 25    Puma yagouaroundi                           <p>Ex-ruta 12<br /> </p>
# ...                 ...                                                ...
# 2013  Puma yagouaroundi                     <p>Portal de Acc. (mastil)</p>
# 2014  Puma yagouaroundi                      <p>A.C, ex Acceso al area</p>
# 2015  Puma yagouaroundi                                   <p>Bº Gques.</p>
# 2016  Puma yagouaroundi  <p>AC - curva con araucarias a 50mts lomo de b...
# 2017  Puma yagouaroundi                            <p>Barrio Gpques AC</p>
#
#      stateProvince       lat       lng  elevation   day  month    year  \
# 21        Misiones -25.66906 -54.49880      249.0  30.0    8.0  1998.0
# 22        Misiones -25.68780 -54.45177      184.0  29.0   12.0  1999.0
# 23        Misiones -25.69073 -54.47802      234.0  20.0   12.0  1998.0
# 24        Misiones -25.69822 -54.33917      255.0  17.0   10.0  1991.0
# 25        Misiones -25.70932 -54.44183      212.0  19.0    2.0  2001.0
# ...            ...       ...       ...        ...   ...    ...     ...
# 2013      Misiones -25.68331 -54.45484      179.0   1.0    7.0  2005.0
# 2014      Misiones -25.69013 -54.45898      217.0   3.0    3.0  2005.0
# 2015      Misiones -25.67886 -54.45548      192.0  12.0    1.0  2005.0
# 2016      Misiones -25.65692 -54.45178      179.0  15.0    6.0  2005.0
# 2017      Misiones -25.67886 -54.45548      192.0  24.0    2.0  2004.0
#
#       taxonKey     ScientificName                   VernacularNames
# 21     2435146  Puma yagouaroundi  Jaguarondi Jaguarundi Yaguarundi
# 22     2435146  Puma yagouaroundi  Jaguarondi Jaguarundi Yaguarundi
# 23     2435146  Puma yagouaroundi  Jaguarondi Jaguarundi Yaguarundi
# 24     2435146  Puma yagouaroundi  Jaguarondi Jaguarundi Yaguarundi
# 25     2435146  Puma yagouaroundi  Jaguarondi Jaguarundi Yaguarundi
# ...        ...                ...                               ...
# 2013   2435146  Puma yagouaroundi  Jaguarondi Jaguarundi Yaguarundi
# 2014   2435146  Puma yagouaroundi  Jaguarondi Jaguarundi Yaguarundi
# 2015   2435146  Puma yagouaroundi  Jaguarondi Jaguarundi Yaguarundi
# 2016   2435146  Puma yagouaroundi  Jaguarondi Jaguarundi Yaguarundi
# 2017   2435146  Puma yagouaroundi  Jaguarondi Jaguarundi Yaguarundi
#
# [992 rows x 19 columns]

# %% [markdown]
# ### rt: En Misiones son 992 registros de Pumas

# %% [markdown]
# ## Cálculo: ¿Cuál es el año más reciente con avistajes? ¿Cuál es el promedio de avistajes por año?

# %%
felinos = pd.read_csv("felinos_filtrado.csv")
felinos.sort_values(by="year", ascending=False)
# Out:
#       Unnamed: 0   kingdom    phylum     class      order   family      genus  \
# 350          350  Animalia  Chordata  Mammalia  Carnivora  Felidae       Puma
# 345          345  Animalia  Chordata  Mammalia  Carnivora  Felidae       Puma
# 348          348  Animalia  Chordata  Mammalia  Carnivora  Felidae       Puma
# 349          349  Animalia  Chordata  Mammalia  Carnivora  Felidae       Puma
# 245          245  Animalia  Chordata  Mammalia  Carnivora  Felidae       Puma
# ...          ...       ...       ...       ...        ...      ...        ...
# 1375        1375  Animalia  Chordata  Mammalia  Carnivora  Felidae  Leopardus
# 1376        1376  Animalia  Chordata  Mammalia  Carnivora  Felidae  Leopardus
# 1377        1377  Animalia  Chordata  Mammalia  Carnivora  Felidae  Leopardus
# 1378        1378  Animalia  Chordata  Mammalia  Carnivora  Felidae  Leopardus
# 1379        1379  Animalia  Chordata  Mammalia  Carnivora  Felidae       Puma
#
#                  species                                           locality  \
# 350        Puma concolor  <p>Ruta Provincial Nº 15 entre la Planta Estab...
# 345        Puma concolor                            <p>Seccional Moyano</p>
# 348        Puma concolor                      <p>Seccional Lago Roca II</p>
# 349        Puma concolor  <p>Lago Roca, sendero entre Cerro Cristal y Al...
# 245        Puma concolor                           <p>Seccional La Vega</p>
# ...                  ...                                                ...
# 1375    Leopardus wiedii      El Doradito,Parque Provincial Isla Caraguatay
# 1376    Leopardus wiedii      El Doradito,Parque Provincial Isla Caraguatay
# 1377  Leopardus pardalis      El Doradito,Parque Provincial Isla Caraguatay
# 1378  Leopardus pardalis      El Doradito,Parque Provincial Isla Caraguatay
# 1379   Puma yagouaroundi  Arroyo Doradito,Parque Provincial Isla Caraguatay
#
#      stateProvince       lat       lng  elevation   day  month    year  \
# 350     Santa Cruz -50.53166 -72.79222        0.0   1.0    2.0  2012.0
# 345     Santa Cruz -49.66835 -72.88147        0.0   6.0    1.0  2012.0
# 348     Santa Cruz -50.52250 -72.77722        0.0  18.0    4.0  2012.0
# 349     Santa Cruz -50.52547 -72.77660        0.0  13.0    4.0  2012.0
# 245        Neuquén -38.99340 -70.37680     1309.0   8.0    3.0  2012.0
# ...            ...       ...       ...        ...   ...    ...     ...
# 1375      Misiones -26.61667 -54.80000        NaN   NaN    NaN     NaN
# 1376      Misiones -26.61667 -54.80000        NaN   NaN    NaN     NaN
# 1377      Misiones -26.61667 -54.80000        NaN   NaN    NaN     NaN
# 1378      Misiones -26.61667 -54.80000        NaN   NaN    NaN     NaN
# 1379      Misiones -26.61667 -54.80000        NaN   NaN    NaN     NaN
#
#       taxonKey      ScientificName  \
# 350    2435099       Puma concolor
# 345    2435099       Puma concolor
# 348    2435099       Puma concolor
# 349    2435099       Puma concolor
# 245    2435099       Puma concolor
# ...        ...                 ...
# 1375   2434950    Leopardus wiedii
# 1376   2434950    Leopardus wiedii
# 1377   2434982  Leopardus pardalis
# 1378   2434982  Leopardus pardalis
# 1379   2435156   Puma yagouaroundi
#
#                                         VernacularNames
# 350   Red tiger Puma Cougar León colorado Onza berme...
# 345   Red tiger Puma Cougar León colorado Onza berme...
# 348   Red tiger Puma Cougar León colorado Onza berme...
# 349   Red tiger Puma Cougar León colorado Onza berme...
# 245   Red tiger Puma Cougar León colorado Onza berme...
# ...                                                 ...
# 1375  Margay Caucel Baumozelot Tigrillo Tree ocelot ...
# 1376  Margay Caucel Baumozelot Tigrillo Tree ocelot ...
# 1377  Gato onza Ocelote Tigrillo Ozelot Ocelot Manig...
# 1378  Gato onza Ocelote Tigrillo Ozelot Ocelot Manig...
# 1379                   Jaguarondi Jaguarundi Yaguarundi
#
# [2019 rows x 19 columns]

# %% [markdown]
# ### rt: El avistaje más reciente fue en 2012

# %%
print(felinos["year"].mean())
# Out:
# 2003.8147590361446

# %% [markdown]
# ### rt: El año promedio de avistajes es el de 2003

# %% [markdown]
# ## Gráfico: Realizar un gráfico con la cantidad de avistajes por especie. Realizar un gráfico con la evolución anual de avistajes (cantidad por año).

# %%
felinos_species = felinos["species"].value_counts()
px.bar(data_frame=felinos_species, x=felinos_species.index, y=felinos_species.values, title="Cantidad de avistajes por especie").show()

# %%
felinos_año = felinos["year"].value_counts()
px.bar(data_frame=felinos_año, x=felinos_año.index, y=felinos_año.values, title="Cantidad de avistajes por por año").show()

# %% [markdown]
# ## Mapa: Generar un mapa con todos los avistamientos de Puma concolor, coloreando según el año de avistaje.

# %%
def generar_mapa():
    attr = (
        '&copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> '
        'contributors, &copy; <a href="https://cartodb.com/attributions">CartoDB</a>'
    )
    
    tiles = 'https://wms.ign.gob.ar/geoserver/gwc/service/tms/1.0.0/capabaseargenmap@EPSG%3A3857@png/{z}/{x}/{-y}.png'
    m = fl.Map(
        location=(-33.457606, -65.346857),
        control_scale=True,
        zoom_start=5,
        name='es',
        tiles=tiles,
        attr=attr
    )
    return m

# %%
mapa=generar_mapa()

# %%
puma_concolor= felinos[felinos["species"]== "Puma concolor"]

# %%
def agregar_marca_puma(row):
    colores = {2008: 'red', 2009: 'blue', 2010: 'green', 2011:"gray",2012:"yellow"}
    color = colores.get(row["year"])
    
    fl.CircleMarker( 
        location=[row['lat'], row['lng']],
        radius=6,
        color=color,
        fill=True,
        fill_color=color,
        popup=row["year"]
        ).add_to(mapa)

# %%
puma_concolor.apply(agregar_marca_puma, axis=1)
# Out:
# 114     None
# 115     None
# 116     None
# 117     None
# 118     None
#         ...
# 1879    None
# 1880    None
# 1881    None
# 1882    None
# 2018    None
# Length: 1297, dtype: object

# %%
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9fb0d8beb96d28bd5a4074dd67f419c6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9fb0d8beb96d28bd5a4074dd67f419c6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9fb0d8beb96d28bd5a4074dd67f419c6 = L.map(
#                 &quot;map_9fb0d8beb96d28bd5a4074dd67f419c6&quot;,
#                 {
#                     center: [-33.457606, -65.346857],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;name&quot;: &quot;es&quot;,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_9fb0d8beb96d28bd5a4074dd67f419c6);
#
#
#
#
#
#             var tile_layer_85cd919b3c01d3b262c19268ff949c1f = L.tileLayer(
#                 &quot;https://wms.ign.gob.ar/geoserver/gwc/service/tms/1.0.0/capabaseargenmap@EPSG%3A3857@png/{z}/{x}/{-y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors, \u0026copy; \u003ca href=\&quot;https://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_85cd919b3c01d3b262c19268ff949c1f.addTo(map_9fb0d8beb96d28bd5a4074dd67f419c6);
#
#
#             tile_layer_85cd919b3c01d3b262c19268ff949c1f.addTo(map_9fb0d8beb96d28bd5a4074dd67f419c6);
#
#
#             var circle_marker_fc96b4124207e369114f52a89e471851 = L.circleMarker(
#                 [-42.10568, -71.72634],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: null, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: null, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9fb0d8beb96d28bd5a4074dd67f419c6);
#
#
#         var popup_d6b2fb8f9183b0acb16f9d3184cff1ba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7f8c0dd2fe2f4121f54a374f59ccb51f = $(`&lt;div id=&quot;html_7f8c0dd2fe2f4121f54a374f59ccb51f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2010.0&lt;/div&gt;`)[0];
#                 popup_d6b2fb8f9183b0acb16f9d3184cff1ba.setContent(html_7f8c0dd2fe2f4121f54a374f59ccb51f);
#
#
#
#         circle_marker_fc96b4124207e369114f52a89e471851.bindPopup(popup_d6b2fb8f9183b0acb16f9d3184cff1ba)
#         ;
#
#
#
#
#             var circle_marker_966e1f72fd5f35098269d02eec6ff4f6 = L.circleMarker(
#                 [-47.75305, -72.1212],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: null, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: null, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9fb0d8beb96d28bd5a4074dd67f419c6);
#
#
#         var popup_0e395f91d595934178217d2aedf7ad8e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_84fed515b69ef2fc0f8b0b708a4ead01 = $(`&lt;div id=&quot;html_84fed515b69ef2fc0f8b0b708a4ead01&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2010.0&lt;/div&gt;`)[0];
#                 popup_0e395f91d595934178217d2aedf7ad8e.setContent(html_84fed515b69ef2fc0f8b0b708a4ead01);
#
#
#
#         circle_marker_966e1f72fd5f35098269d02eec6ff4f6.bindPopup(popup_0e395f91d595934178217d2aedf7ad8e)
#         ;
#
#
#
#
#             var circle_marker_d37e9b9c2aa2cfa598aba294e172a0ea = L.circleMarker(
#                 [-47.75275, -72.11911],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: null, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: null, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9fb0d8beb96d28bd5a4074dd67f419c6);
#
#
#         var popup_8781487127fb35d4ab914df764bfb2d6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f3a190a8e2161ddb8c946ed4a0cd1bb3 = $(`&lt;div id=&quot;html_f3a190a8e2161ddb8c946ed4a0cd1bb3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2010.0&lt;/div&gt;`)[0];
#                 popup_8781487127fb35d4ab914df764bf
